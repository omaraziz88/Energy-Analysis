# %%
import pandas as pd

# %%
co2_emissions = "CO2_Emissions.csv"
crude_ngl_production = "Crude_NGL_Production.csv"
natural_gas_production="Natural_Gas_Production.csv"
renewables_electricity_share="Renewables_Electricity_Share.csv"
solar_wind_share="Solar_and_Wind_Share.csv"
electricity_production="Total_Electricity_Production.csv"
included_columns=['World','OECD','G7','BRICS','Europe','North America','Latin America','Pacific','Africa','Middle-East']

# %%
co2_emissions_df = pd.read_csv(co2_emissions, encoding="ISO-8859-1")
co2_emissions_df.set_index('Country',inplace=True)
co2_emissions_df.head()
co2_emissions_df_transposed=co2_emissions_df.T
co2_emissions_df_transposed.head()
# Out:
# Country     World      OECD       G7    BRICS   Europe  European Union  \
# 1990     20277.70  11174.87  8575.88  5411.20  4417.64         4115.02
# 1991     20428.88  11205.76  8549.52  5573.58  4392.06         4099.76
# 1992     20389.24  11267.76  8599.21  5544.03  4270.49         3981.31
# 1993     20483.38  11357.11  8665.63  5584.72  4181.88         3896.36
# 1994     20569.16  11540.20  8776.88  5532.00  4135.39         3863.83
#
# Country  Belgium  Czech Rep.  France  Germany    ...      Egypt  Nigeria  \
# 1990      105.89      151.25  357.02   955.79    ...      78.50    28.32
# 1991      110.43      139.65  383.18   938.81    ...      77.18    33.59
# 1992      109.48      134.20  372.34   899.60    ...      80.06    40.14
# 1993      108.16      132.72  354.24   889.54    ...      81.83    36.64
# 1994      113.65      125.87  346.94   874.38    ...      77.46    30.85
#
# Country  South Africa  Middle-East    Iran  Kuwait  Saudi Arabia  \
# ...

# %%
co2_emissions_df_transposed.drop(co2_emissions_df_transposed.columns.difference(included_columns), 1, inplace=True)
co2_emissions_df_transposed.plot(kind='line')

# %%
crude_ngl_production_df = pd.read_csv(crude_ngl_production, encoding="ISO-8859-1")
crude_ngl_production_df.set_index('Country',inplace=True)
crude_ngl_production_df.head()
crude_ngl_production_transposed=crude_ngl_production_df.T
crude_ngl_production_transposed.head()
# Out:
# Country   World   OECD     G7  BRICS  Europe  European Union  Belgium  \
# 1990     3176.0  895.0  611.0  734.0   220.0           132.0      0.0
# 1991     3175.0  914.0  610.0  680.0   231.0           131.0      0.0
# 1992     3215.0  929.0  612.0  608.0   247.0           134.0      0.0
# 1993     3242.0  936.0  611.0  568.0   260.0           139.0      0.0
# 1994     3272.0  971.0  633.0  540.0   302.0           168.0      0.0
#
# Country  Czech Rep.  France  Germany    ...      Egypt  Nigeria  South Africa  \
# 1990            0.0     3.0      6.0    ...       45.0     88.0           4.0
# 1991            0.0     4.0      5.0    ...       45.0     92.0           4.0
# 1992            0.0     4.0      4.0    ...       46.0     96.0           6.0
# 1993            0.0     3.0      4.0    ...       48.0     97.0           7.0
# 1994            0.0     3.0      4.0    ...       46.0     96.0           7.0
#
# Country  Middle-East   Iran  Kuwait  Saudi Arabia  United Arab Emirates  \
# ...

# %%
crude_ngl_production_transposed.drop(crude_ngl_production_transposed.columns.difference(included_columns), 1, inplace=True)
crude_ngl_production_transposed.plot(kind='line')

# %%
natural_gas_production_df= pd.read_csv(natural_gas_production, encoding="ISO-8859-1")
natural_gas_production_df.head()
natural_gas_production_df.set_index('country',inplace=True)
natural_gas_production_transposed=natural_gas_production_df.T
natural_gas_production_transposed.head()
# Out:
# country   World   OECD     G7  BRICS  Europe  European Union  Belgium  \
# 1990     2058.0  881.0  707.0  663.0   242.0           213.0      0.0
# 1991     2102.0  903.0  717.0  668.0   257.0           228.0      0.0
# 1992     2102.0  922.0  732.0  667.0   255.0           225.0      0.0
# 1993     2148.0  958.0  763.0  647.0   269.0           239.0      0.0
# 1994     2166.0  995.0  801.0  638.0   269.0           237.0      0.0
#
# country  Czech Rep.  France  Germany    ...      Egypt  Nigeria  South Africa  \
# 1990            0.0     3.0     19.0    ...        8.0      4.0           2.0
# 1991            0.0     3.0     19.0    ...        9.0      5.0           2.0
# 1992            0.0     3.0     19.0    ...       10.0      5.0           2.0
# 1993            0.0     3.0     19.0    ...       12.0      6.0           2.0
# 1994            0.0     4.0     20.0    ...       12.0      5.0           2.0
#
# country  Middle-East  Iran  Kuwait  Saudi Arabia  United Arab Emirates  \
# ...

# %%
natural_gas_production_transposed.drop(natural_gas_production_transposed.columns.difference(included_columns), 1, inplace=True)
natural_gas_production_transposed.dtypes
# natural_gas_production_transposed.plot(kind='line')
# Out:
# country
# World            float64
# OECD             float64
# G7               float64
# BRICS            float64
# Europe           float64
# North America    float64
# Latin America    float64
# Pacific          float64
# Africa           float64
# Middle-East      float64
# dtype: object

# %%
renewable_share_df= pd.read_csv(renewables_electricity_share, encoding="ISO-8859-1")
renewable_share_df.head()
renewable_share_df.set_index('Country',inplace=True)
renewable_share_transposed=renewable_share_df.T
renewable_share_transposed.head()
# Out:
# Country  World   OECD     G7  BRICS Europe European Union Belgium Czech Rep.  \
# 1990     19.74  17.71  15.11  24.22  18.08          12.63    1.67       2.32
# 1991     19.66  17.45  15.09  23.96  18.21          12.95    1.79       2.18
# 1992     19.58  17.36   14.7   24.1  19.13          13.64    1.98       2.76
# 1993     20.21  17.93  15.13  24.72   19.7           13.9     1.8       2.98
# 1994     19.96  16.94  14.47   25.7  19.64          14.15    1.99       3.57
#
# Country France Germany    ...     Egypt Nigeria South Africa Middle-East  \
# 1990      14.1     3.9    ...      23.5   32.59          1.7        4.88
# 1991     13.97    3.85    ...     22.35   41.86         2.25        4.56
# 1992     16.12    4.38    ...     21.24   40.85         1.24        4.87
# 1993     14.79    4.62    ...     21.94   38.41         0.85        4.46
# 1994     17.45    5.18    ...     22.25   35.81         1.43        3.46
#
# ...

# %%
renewable_share_transposed.drop(renewable_share_transposed.columns.difference(included_columns), 1, inplace=True)
renewable_share_transposed = renewable_share_transposed.convert_objects(convert_numeric=True)
renewable_share_transposed.dtypes
renewable_share_transposed.plot(kind='line')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
solar_wind_share_df= pd.read_csv(solar_wind_share, encoding="ISO-8859-1")
solar_wind_share_df.head()
solar_wind_share_df.set_index('Country',inplace=True)
solar_wind_share_transposed=solar_wind_share_df.T
solar_wind_share_transposed.head()
# Out:
# Country  World  OECD    G7  BRICS  Europe  European Union  Belgium  \
# 1990      0.35  0.44  0.42   0.01    0.18            0.18     0.01
# 1991      0.35  0.44  0.41   0.01    0.18            0.19     0.01
# 1992      0.37  0.47  0.44   0.01    0.22            0.23     0.01
# 1993      0.38  0.48  0.45   0.01    0.26            0.27     0.01
# 1994      0.39  0.48  0.46   0.01    0.28            0.30     0.01
#
# Country  Czech Rep.  France  Germany    ...      Egypt  Nigeria  South Africa  \
# 1990            0.0    0.12     0.01    ...        0.0      0.0           0.0
# 1991            0.0    0.11     0.04    ...        0.0      0.0           0.0
# 1992            0.0    0.11     0.05    ...        0.0      0.0           0.0
# 1993            0.0    0.10     0.13    ...        0.0      0.0           0.0
# 1994            0.0    0.11     0.27    ...        0.0      0.0           0.0
#
# Country  Middle-East  Iran  Kuwait  Saudi Arabia  United Arab Emirates  \
# ...

# %%
solar_wind_share_transposed.drop(solar_wind_share_transposed.columns.difference(included_columns), 1, inplace=True)
solar_wind_share_transposed.plot(kind='line')

# %%
electricity_production_df=pd.read_csv(electricity_production, encoding="ISO-8859-1")
electricity_production_df.head()
electricity_production_df.set_index('Country',inplace=True)
electricity_production_transposed=electricity_production_df.T
electricity_production_transposed.head()
# Out:
# Country    World    OECD      G7   BRICS  Europe  European Union  Belgium  \
# 1990     11894.0  7712.0  6089.0  2386.0  2900.0          2595.0     71.0
# 1991     12173.0  7900.0  6236.0  2468.0  2937.0          2640.0     72.0
# 1992     12284.0  7975.0  6277.0  2510.0  2926.0          2624.0     72.0
# 1993     12574.0  8160.0  6414.0  2583.0  2931.0          2626.0     71.0
# 1994     12881.0  8389.0  6578.0  2637.0  2976.0          2667.0     72.0
#
# Country  Czech Rep.  France  Germany    ...      Egypt  Nigeria  South Africa  \
# 1990           63.0   421.0    550.0    ...       42.0     13.0         167.0
# 1991           61.0   456.0    540.0    ...       44.0     14.0         168.0
# 1992           59.0   464.0    537.0    ...       46.0     15.0         168.0
# 1993           59.0   473.0    526.0    ...       48.0     15.0         175.0
# 1994           59.0   477.0    529.0    ...       49.0     16.0         182.0
#
# ...

# %%
electricity_production_transposed.drop(electricity_production_transposed.columns.difference(included_columns), 1, inplace=True)
electricity_production_transposed.plot(kind='line')
